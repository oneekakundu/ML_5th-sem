# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv("C:\\Users\\USER\\Downloads\\penguins_binary.csv")

# %%
df.shape
# Out:
# (1201, 7)

# %%
df.head()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Gentoo  Biscoe       51.211594      10.784101                198
# 1  Gentoo  Biscoe       54.473814      16.435158                208
# 2  Adelie  Biscoe       44.907998      25.894140                204
# 3  Adelie   Dream       26.304201      13.736113                160
# 4  Adelie  Biscoe       54.870708      14.800691                210
#
#    body_mass_g     sex
# 0         6536  female
# 1         4077  female
# 2         3665  female
# 3         8000    male
# 4         5418    male

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()

# Create new columns for encoded values
df['Species_n'] = LE.fit_transform(df['species'])
df['Island_n']  = LE.fit_transform(df['island'])
df['Sex_n'] = LE.fit_transform(df['sex'])

# %%
df.drop(axis=1,columns='sex',inplace=True)
df.drop(axis=1,columns='species',inplace=True)
df.drop(axis=1,columns='island',inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Species_n', axis=1)
y = df['Species_n']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20,random_state=2)

# %%
forest = RandomForestClassifier()
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = forest.predict(X_test)

# %%
forest.score(X_test, y_test)
# Out:
# 0.9543568464730291

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[116   5]
#  [  6 114]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       121
#            1       0.96      0.95      0.95       120
#
#     accuracy                           0.95       241
#    macro avg       0.95      0.95      0.95       241
# weighted avg       0.95      0.95      0.95       241
