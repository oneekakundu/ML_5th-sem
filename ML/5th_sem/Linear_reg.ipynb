# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score,root_mean_squared_error,r2_score,mean_squared_error,median_absolute_error

# %%
df= pd.read_csv("C:\\Users\\ONEEKA\\Downloads\\Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'SepalLengthCm'}>],
#        [<Axes: title={'center': 'SepalWidthCm'}>,
#         <Axes: title={'center': 'PetalLengthCm'}>],
#        [<Axes: title={'center': 'PetalWidthCm'}>, <Axes: >]], dtype=object)

# %%
X=df[['SepalLengthCm']]
Y=df['PetalLengthCm']

# %%
plt.scatter(X,Y,marker="*")
plt.xlabel('SepalLengthCm')
plt.ylabel('PetalLengthCm')
plt.title('Iris')
# Out:
# Text(0.5, 1.0, 'Iris')

# %%
X_train,X_test,Y_train,Y_Test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
lr=linear_model.LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(X_test)
pred
# Out:
# array([1.49624568, 1.49624568, 3.50231871, 1.86098623, 1.86098623,
#        6.23787284, 2.22572678, 5.32602146, 4.77891063, 1.86098623,
#        2.7728376 , 1.13150513, 2.22572678, 2.95520788, 4.04942953,
#        4.96128091, 1.3138754 , 3.50231871, 5.32602146, 3.13757816,
#        5.32602146, 4.77891063, 4.77891063, 3.31994843, 4.59654036,
#        1.67861595, 1.67861595, 4.23179981, 2.40809705, 6.23787284])

# %%
plt.scatter(X_train,Y_train)
plt.plot(X_test,pred,color='red')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 plt.scatter(X_train,Y_train)
# ----> 2 plt.xlabel('SepalLengthCm')
#       3 plt.plot(X_test,pred,color='red')
#
# TypeError: 'str' object is not callable

# %%
plt.scatter(X_test,Y_Test)
plt.plot(X_test,pred, color= 'red')

# %%
lr.intercept_
# Out:
# -6.892786988317556

# %%
lr.coef_
# Out:
# array([1.82370275])

# %%
metrics.mean_absolute_error(Y_Test,pred)
# Out:
# 0.5224475337946191

# %%
metrics.mean_squared_error(Y_Test,pred)
# Out:
# 0.4157443623029572

# %%
metrics.r2_score(Y_Test,pred)
# Out:
# 0.870824886307559

# %%
metrics.root_mean_squared_error(Y_Test,pred)
# Out:
# 0.6447824146973591

# %%
lr.score(X_test,Y_Test)#R2 score
# Out:
# 0.870824886307559
