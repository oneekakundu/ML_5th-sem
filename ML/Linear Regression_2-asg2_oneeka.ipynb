# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("C:\\Users\\ONEEKA\\Downloads\\penguins.csv")
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            41.5           20.0                186
# 4       Adelie  Torgersen            36.7           19.3                193
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8                207
# 340  Chinstrap      Dream            43.5           18.1                202
# 341  Chinstrap      Dream            49.6           18.2                193
# 342  Chinstrap      Dream            50.8           19.0                210
# 343  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex
# 0           3750    male
# ...

# %%
plt.scatter(df.bill_length_mm,df.body_mass_g,color='red',marker='*')
plt.xlabel('Bill length')
plt.ylabel('Body mass')
# Out:
# Text(0, 0.5, 'Body mass')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['bill_length_mm']],df.body_mass_g)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([87.64942098])

# %%
reg.intercept_
# Out:
# 352.43096799341765

# %%
p=reg.predict(df[['bill_length_mm']])
p
plt.xlabel('bill_length_mm',fontsize=20)
plt.ylabel('body_mass_g',fontsize=20)
plt.scatter(df.bill_length_mm,df.body_mass_g,color='red',marker='*')
plt.plot(df.bill_length_mm,reg.predict(df[['bill_length_mm']]),color='blue')

# %%
import seaborn as sns
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df_binary = df[['flipper_length_mm', 'body_mass_g']].copy()
df_binary_columns = ['flipper_length_mm', 'body_mass_g']
df_binary.head()
# Out:
#    flipper_length_mm  body_mass_g
# 0                181         3750
# 1                186         3800
# 2                195         3250
# 3                186         3450
# 4                193         3450

# %%
x = df['flipper_length_mm']
y = df['body_mass_g']

# %%
x
# Out:
# 0      181
# 1      186
# 2      195
# 3      186
# 4      193
#       ...
# 339    207
# 340    202
# 341    193
# 342    210
# 343    198
# Name: flipper_length_mm, Length: 344, dtype: int64

# %%
y
# Out:
# 0      3750
# 1      3800
# 2      3250
# 3      3450
# 4      3450
#        ...
# 339    4000
# 340    3400
# 341    3775
# 342    4100
# 343    3775
# Name: body_mass_g, Length: 344, dtype: int64

# %%
X = np.array(df_binary['flipper_length_mm']).reshape(-1,1)
Y = np.array(df_binary['body_mass_g']).reshape(-1,1)
#df_binary.dropna(inplace=True)
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.33)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(x_test)
print(pred)
# Out:
# [[5115.25626885]
#  [5211.13906427]
#  [3533.19014447]
#  [3581.13154218]
#  [4300.25250781]
#  [4396.13530322]
#  [3916.72132614]
#  [3533.19014447]
#  [4204.36971239]
#  [4923.49067802]
#  [3820.83853072]
#  [4300.25250781]
#  [4252.3111101 ]
#  [3916.72132614]
#  [5498.78745052]
#  [3629.07293989]
#  [3916.72132614]
#  [3820.83853072]
#  [3293.48315593]
#  [3101.71756509]
#  [4923.49067802]
#  [4635.84229176]
#  [3629.07293989]
#  [4827.6078826 ]
#  [4779.66648489]
#  [4539.95949635]
#  [4779.66648489]
#  [4923.49067802]
#  [4492.01809864]
#  [4971.43207572]
#  [5498.78745052]
#  [3724.9557353 ]
#  [4827.6078826 ]
#  [3964.66272385]
#  [4875.54928031]
#  [3964.66272385]
#  [5067.31487114]
#  [4683.78368947]
#  [4827.6078826 ]
#  [4204.36971239]
#  [3533.19014447]
#  [5354.96325739]
#  [3916.72132614]
#  [3724.9557353 ]
#  [4060.54551926]
#  [3820.83853072]
#  [3820.83853072]
#  [3677.0143376 ]
#  [3293.48315593]
#  [4875.54928031]
#  [3916.72132614]
#  [5019.37347343]
# ...

# %%
plt.scatter(x_train,y_train)
plt.plot(x_test,pred,color='red')

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,pred,color='red')

# %%
from sklearn import metrics

# Mean Squared Error (MSE)
mse = metrics.mean_squared_error(y_test, pred)

# Root Mean Squared Error (RMSE)
rmse = mse ** 0.5

# Mean Absolute Error (MAE)
mae = metrics.mean_absolute_error(y_test, pred)

# R² Score (Coefficient of Determination)
r2 = metrics.r2_score(y_test, pred)

print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 137507.66145944246
# Root Mean Squared Error: 370.8202549206859
# Mean Absolute Error: 293.42005473056213
# R² Score: 0.7922182161752045

# %%
plt.scatter(df.body_mass_g,df.flipper_length_mm,color='red',marker='*')
plt.xlabel('body_mass_g')
plt.ylabel('flipper_length_mm')
# Out:
# Text(0, 0.5, 'flipper_length_mm')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['body_mass_g']],df.body_mass_g)
# Out:
# LinearRegression()

# %%
X = np.array(df_binary['body_mass_g']).reshape(-1,1)
Y = np.array(df_binary['flipper_length_mm']).reshape(-1,1)
#df_binary.dropna(inplace=True)
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.33)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(x_test)
print(pred)
# Out:
# [[211.79066723]
#  [196.0876121 ]
#  [190.10549586]
#  [209.17349138]
#  [206.93019779]
#  [200.20031702]
#  [195.33984757]
#  [182.62785056]
#  [207.67796232]
#  [192.72267171]
#  [221.13772386]
#  [189.35773133]
#  [198.70478796]
#  [208.42572685]
#  [198.70478796]
#  [199.45255249]
#  [183.74949735]
#  [202.44361061]
#  [203.93913967]
#  [200.20031702]
#  [214.40784309]
#  [197.20925889]
#  [192.72267171]
#  [214.40784309]
#  [189.73161359]
#  [188.23608453]
#  [197.20925889]
#  [197.95702342]
#  [196.46149436]
#  [190.10549586]
#  [219.6421948 ]
#  [217.39890121]
#  [208.79960911]
#  [199.07867022]
#  [213.66007856]
#  [184.12337962]
#  [204.6869042 ]
#  [193.84431851]
#  [220.38995933]
#  [187.86220227]
#  [212.91231403]
#  [186.74055547]
#  [206.93019779]
#  [181.50620376]
#  [225.62431104]
#  [202.44361061]
#  [215.15560762]
#  [196.46149436]
#  [210.66902044]
#  [211.41678497]
#  [192.72267171]
#  [186.74055547]
#  [218.89443027]
#  [194.59208304]
#  [227.86760463]
# ...

# %%
plt.scatter(x_train,y_train)
plt.plot(x_test,pred,color='red')

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,pred,color='red')

# %%
from sklearn import metrics

# Mean Squared Error (MSE)
mse = metrics.mean_squared_error(y_test, pred)

# Root Mean Squared Error (RMSE)
rmse = mse ** 0.5

# Mean Absolute Error (MAE)
mae = metrics.mean_absolute_error(y_test, pred)

# R² Score (Coefficient of Determination)
r2 = metrics.r2_score(y_test, pred)

print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 40.775141244056414
# Root Mean Squared Error: 6.385541577975702
# Mean Absolute Error: 5.0041453845108315
# R² Score: 0.7982898530482196
