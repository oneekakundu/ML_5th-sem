# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv("C:\\Users\\ONEEKA\Downloads\\penguins_binary.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\ONEEKA\AppData\Local\Temp\ipykernel_18384\3265348400.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df= pd.read_csv("C:\\Users\\ONEEKA\Downloads\\penguins_binary.csv")

# %%
df.shape
# Out:
# (1201, 7)

# %%
df.head(10)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Gentoo     Biscoe       51.211594      10.784101                198
# 1  Gentoo     Biscoe       54.473814      16.435158                208
# 2  Adelie     Biscoe       44.907998      25.894140                204
# 3  Adelie      Dream       26.304201      13.736113                160
# 4  Adelie     Biscoe       54.870708      14.800691                210
# 5  Gentoo     Biscoe       48.534629      15.329506                224
# 6  Gentoo     Biscoe       57.311291      55.000000                211
# 7  Adelie     Biscoe       28.576889      30.000000                241
# 8  Adelie     Biscoe       38.120374      22.324065                169
# 9  Adelie  Torgersen       36.250178      18.637415                182
#
#    body_mass_g     sex
# 0         6536  female
# 1         4077  female
# 2         3665  female
# 3         8000    male
# 4         5418    male
# 5         3479  female
# 6         4975  female
# 7         2000    male
# 8         3869    male
# 9         5308    male

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()

# Create new columns for encoded values
df['Species_n'] = LE.fit_transform(df['species'])
df['Island_n']  = LE.fit_transform(df['island'])
df['Sex_n'] = LE.fit_transform(df['sex'])

# %%
df.drop(axis=1,columns='sex',inplace=True)
df.drop(axis=1,columns='species',inplace=True)
df.drop(axis=1,columns='island',inplace=True)

# %%
X = df.drop('Species_n', axis=1)
y = df['Species_n']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20,random_state=2)

# %%
# PROCESS 1
#seed=7
num_trees=10
model = AdaBoostClassifier(n_estimators=num_trees)

# %%
kfold=model_selection.KFold(n_splits=5)
results = model_selection.cross_val_score(model,X_train, y_train, cv=kfold)
# Out:
# D:\Anaconda_Navigator\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# D:\Anaconda_Navigator\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# D:\Anaconda_Navigator\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# D:\Anaconda_Navigator\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# D:\Anaconda_Navigator\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
print("Results:", results)
print("Mean Results:", results.mean())
# Out:
# Results: [0.96875    0.89583333 0.93229167 0.91145833 0.9375    ]
# Mean Results: 0.9291666666666668

# %%
#PROCESS 2
model = AdaBoostClassifier(n_estimators=num_trees)
model.fit(X_train, y_train)
# Out:
# D:\Anaconda_Navigator\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier(n_estimators=10)

# %%
y_pred = model.predict(X_test)

# %%
model.score(X_test, y_test)
# Out:
# 0.9543568464730291

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[119   2]
#  [  9 111]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       121
#            1       0.98      0.93      0.95       120
#
#     accuracy                           0.95       241
#    macro avg       0.96      0.95      0.95       241
# weighted avg       0.96      0.95      0.95       241
