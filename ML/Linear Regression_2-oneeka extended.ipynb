# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("C:\\Users\\ONEEKA\\Downloads\\penguins.csv")
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            41.5           20.0                186
# 4       Adelie  Torgersen            36.7           19.3                193
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8                207
# 340  Chinstrap      Dream            43.5           18.1                202
# 341  Chinstrap      Dream            49.6           18.2                193
# 342  Chinstrap      Dream            50.8           19.0                210
# 343  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex
# 0           3750    male
# 1           3800  female
# 2           3250  female
# 3           3450     NaN
# 4           3450  female
# ..           ...     ...
# 339         4000    male
# 340         3400  female
# 341         3775    male
# 342         4100    male
# 343         3775  female
#
# [344 rows x 7 columns]

# %%
plt.scatter(df.bill_length_mm,df.body_mass_g,color='red',marker='*')
plt.xlabel('bill_length_mm',fontsize=20)
plt.ylabel('body_mass_g',fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 plt.scatter(df.bill_length_mm,df.body_mass_g,color='red',marker='*')
#       2 plt.xlabel('bill_length_mm',fontsize=20)
# ----> 3 plt.ylabel('body_mass_g',fontsize=20)
#
# TypeError: 'str' object is not callable

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['bill_length_mm']],df.body_mass_g)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([87.64942098])

# %%
reg.intercept_
# Out:
# 352.43096799341765

# %%
p=reg.predict(df[['bill_length_mm']])
p
plt.xlabel('bill_length_mm',fontsize=20)
plt.ylabel('body_mass_g',fontsize=20)
plt.scatter(df.bill_length_mm,df.body_mass_g,color='red',marker='*')
plt.plot(df.bill_length_mm,reg.predict(df[['bill_length_mm']]),color='blue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 p
#       3 plt.xlabel('bill_length_mm',fontsize=20)
# ----> 4 plt.ylabel('body_mass_g',fontsize=20)
#       5 plt.scatter(df.bill_length_mm,df.body_mass_g,color='red',marker='*')
#       6 plt.plot(df.bill_length_mm,reg.predict(df[['bill_length_mm']]),color='blue')
#
# TypeError: 'str' object is not callable

# %%
import seaborn as sns
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df_binary = df[['flipper_length_mm', 'body_mass_g']].copy()
df_binary_columns = ['flipper_length_mm', 'body_mass_g']
df_binary.head()

# %%
x = df['flipper_length_mm']
y = df['body_mass_g']

# %%
x

# %%
y

# %%
X = np.array(df_binary['flipper_length_mm']).reshape(-1,1)
Y = np.array(df_binary['body_mass_g']).reshape(-1,1)
#df_binary.dropna(inplace=True)
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.33)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)

# %%
pred = lr.predict(x_test)
print(pred)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_test,pred,color='red')

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,pred,color='red')
